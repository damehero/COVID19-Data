# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # plotting data

# %%
# Load individual date data from US county cases
m3_22_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv')
m3_23_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv')
m3_24_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-24-2020.csv')
m3_25_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-25-2020.csv')
m3_26_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv')
m3_27_2020 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv')

# %%
m3_22_2020.head()
# Out:
#       FIPS         Admin2 Province_State Country_Region    Last_Update  \
# 0  36061.0  New York City       New York             US  3/22/20 23:45
# 1  36059.0         Nassau       New York             US  3/22/20 23:45
# 2  36119.0    Westchester       New York             US  3/22/20 23:45
# 3  36103.0        Suffolk       New York             US  3/22/20 23:45
# 4  36087.0       Rockland       New York             US  3/22/20 23:45
#
#          Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 0  40.767273 -73.971526       9654      63          0       0
# 1  40.740665 -73.589419       1900       4          0       0
# 2  41.162784 -73.757417       1873       0          0       0
# 3  40.883201 -72.801217       1034       9          0       0
# 4  41.150279 -74.025605        455       1          0       0
#
#                   Combined_Key
# 0  New York City, New York, US
# 1         Nassau, New York, US
# 2    Westchester, New York, US
# 3        Suffolk, New York, US
# ...

# %%
# Extracting California county cases on March 22
m3_22_2020 = m3_22_2020.iloc[97:137, np.r_[1:3, 7:11]]
m3_22_2020 = m3_22_2020.sort_values('Admin2')
m3_22_2020
# Out:
#               Admin2 Province_State  Confirmed  Deaths  Recovered  Active
# 103          Alameda     California         71       0          0       0
# 133           Amador     California          1       0          0       0
# 135            Butte     California          1       0          0       0
# 127        Calaveras     California          2       0          0       0
# 104     Contra Costa     California         61       1          0       0
# 120           Fresno     California          6       0          0       0
# 126         Humboldt     California          2       0          0       0
# 121         Imperial     California          6       0          0       0
# 124             Kern     California          5       0          0       0
# 97       Los Angeles     California        407       5          0       0
# 125           Madera     California          3       0          0       0
# 106            Marin     California         38       0          0       0
# ...

# %%
# Extract the  columns that have information on California county cases
m3_23_2020= m3_23_2020.loc[m3_23_2020['Province_State'] == 'California']
m3_23_2020 = m3_23_2020[['Admin2', 'Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active']]

m3_24_2020= m3_24_2020.loc[m3_24_2020['Province_State'] == 'California']
m3_24_2020 = m3_24_2020[['Admin2', 'Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active']]

m3_25_2020= m3_25_2020.loc[m3_25_2020['Province_State'] == 'California']
m3_25_2020 = m3_25_2020[['Admin2', 'Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active']]

m3_26_2020= m3_26_2020.loc[m3_26_2020['Province_State'] == 'California']
m3_26_2020 = m3_26_2020[['Admin2', 'Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active']]

m3_27_2020= m3_27_2020.loc[m3_27_2020['Province_State'] == 'California']
m3_27_2020 = m3_27_2020[['Admin2', 'Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active']]

# %%
m3_27_2020
# Out:
#                Admin2 Province_State  Confirmed  Deaths  Recovered  Active
# 25            Alameda     California        118       1          0       0
# 53             Alpine     California          0       0          0       0
# 54             Amador     California          1       0          0       0
# 330             Butte     California          2       0          0       0
# 339         Calaveras     California          2       0          0       0
# 615            Colusa     California          0       0          0       0
# 624      Contra Costa     California         71       1          0       0
# 756         Del Norte     California          0       0          0       0
# 858         El Dorado     California          2       0          0       0
# 991            Fresno     California          6       0          0       0
# 1052            Glenn     California          0       0          0       0
# ...
